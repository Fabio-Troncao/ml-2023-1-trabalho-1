# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Lendo o arquivo
df = pd.read_excel('dataset.xlsx')

# Verificando dados faltantes, informo e substituindo por True
print(df.isnull().sum())
print(f'Quantidade de campos vazios ou nulos: {df.isnull().sum().sum()}')
df.fillna(True, inplace=True)

# Verificando inconsistências e dados inválidos
for column in df.columns:
    try:
        # Verificando o tipo de dados
        print(f'Tipo de dados para {column}: {df[column].dtype}')
        
        # Convertendo valores 'not_detected'/'detected' para numéricos
        dataf = df[column].replace({'not_detected': -1, 'detected': 1})
        
        # Verificando os valores mínimos e máximos
        print(f'Valor mínimo para {column}: {np.min(dataf)}')
        print(f'Valor máximo para {column}: {np.max(dataf)}')
        
        # Criando um histograma para visualizar os dados
        plt.hist(dataf, bins=50)
        plt.xlabel(column)
        plt.ylabel('Frequência')
        plt.show()
    except Exception as e:
        print(f'Erro na coluna {column}: {str(e)}')

# outliers        

for column in df.columns:
    try:
        # Calculo os valores de Q1, Q3 e IQR para a coluna atual
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1

        # Calculo os limites inferior e superior para a detecção de outliers
        lim_inf = (1.5 * IQR) - Q1
        lim_sup = (1.5 * IQR) + Q3
        print(f'O limite inferior é: {lim_inf}')
        print(f'O limite superior é: {lim_sup}')

        # Identifico os outliers na coluna atual
        outliers = df[(df[column] < lim_inf) | (df[column] > lim_sup)]

        # Imprimo o número de outliers identificados na coluna atual
        print(f'Número de outliers na coluna {column}: {len(outliers)}')

        # Ploto um gráfico com os valores da coluna atual e os outliers destacados
        fig, ax = plt.subplots()
        ax.hist(df[column], bins=20)
        ax.set_title(column)

        if not outliers.empty:
            ax.plot(outliers[column], np.zeros_like(outliers[column]), 'ro', label='outliers')
            ax.legend()

        plt.show()

    except Exception as e:
        print(f'Erro na coluna {column}: {str(e)}')
# Out:
# Patient ID                                                  0
# Patient age quantile                                        0
# SARS-Cov-2 exam result                                      0
# Patient addmited to regular ward (1=yes, 0=no)              0
# Patient addmited to semi-intensive unit (1=yes, 0=no)       0
#                                                          ...
# HCO3 (arterial blood gas analysis)                       5617
# pO2 (arterial blood gas analysis)                        5617
# Arteiral Fio2                                            5624
# Phosphor                                                 5624
# ctO2 (arterial blood gas analysis)                       5617
# Length: 111, dtype: int64
# Quantidade de campos vazios ou nulos: 551682
# Tipo de dados para Patient ID: object
# Valor mínimo para Patient ID: 001646dfe0e98df
# Valor máximo para Patient ID: fff6cd69cbbfe83
# Tipo de dados para Patient age quantile: int64
# ...

# %%
# Deixei esta parte do codigo aqui para ser mais facil visualizar mas caso nao veja deixarei em cima tambem.

for column in df.columns:
    try:
        # Calculo os valores de Q1, Q3 e IQR para a coluna atual
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1

        # Calculo os limites inferior e superior para a detecção de outliers
        lim_inf = (1.5 * IQR) - Q1
        lim_sup = (1.5 * IQR) + Q3
        print(f'O limite inferior é: {lim_inf}')
        print(f'O limite superior é: {lim_sup}')

        # Identifico os outliers na coluna atual
        outliers = df[(df[column] < lim_inf) | (df[column] > lim_sup)]

        # Imprimo o número de outliers identificados na coluna atual
        print(f'Número de outliers na coluna {column}: {len(outliers)}')

        # Ploto um gráfico com os valores da coluna atual e os outliers destacados
        fig, ax = plt.subplots()
        ax.hist(df[column], bins=20)
        ax.set_title(column)

        if not outliers.empty:
            ax.plot(outliers[column], np.zeros_like(outliers[column]), 'ro', label='outliers')
            ax.legend()

        plt.show()

    except Exception as e:
        print(f'Erro na coluna {column}: {str(e)}')
# Out:
# Erro na coluna Patient ID: unsupported operand type(s) for -: 'str' and 'str'
# O limite inferior é: 11.0
# O limite superior é: 29.0
# Número de outliers na coluna Patient age quantile: 3110
# Erro na coluna SARS-Cov-2 exam result: unsupported operand type(s) for -: 'str' and 'str'
# O limite inferior é: 0.0
# O limite superior é: 0.0
# Número de outliers na coluna Patient addmited to regular ward (1=yes, 0=no): 79
# O limite inferior é: 0.0
# O limite superior é: 0.0
# Número de outliers na coluna Patient addmited to semi-intensive unit (1=yes, 0=no): 50
# O limite inferior é: 0.0
# O limite superior é: 0.0
# Número de outliers na coluna Patient addmited to intensive care unit (1=yes, 0=no): 41
# O limite inferior é: -1.0
# O limite superior é: 1.0
# Número de outliers na coluna Hematocrit: 167
# O limite inferior é: -1.0
# O limite superior é: 1.0
# Número de outliers na coluna Hemoglobin: 171
# O limite inferior é: -1.0
# O limite superior é: 1.0
# ...
